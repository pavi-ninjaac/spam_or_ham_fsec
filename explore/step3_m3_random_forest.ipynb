# %%
import pandas as pd
import optuna


from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, accuracy_score, confusion_matrix

# %%
X_train = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/X_train.csv", header=None)
X_test = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/X_test.csv", header=None)
y_train = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/y_train.csv", header=None)
y_test = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/y_test.csv", header=None)



print("X train ",X_train.shape)
print("X test",X_test.shape)
print("Y_Train", y_train.shape)
print("Y_test", y_test.shape)
# Out:
# X train  (4050, 1000)
# X test (375, 1000)
# Y_Train (4050, 1)
# Y_test (375, 1)

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 100)
    max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42,
        class_weight="balanced"
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    precision = f1_score(y_test, y_pred)

    return precision

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print(f"Best hyperparameters: {study.best_params}")
print(f"Best precision: {study.best_value}")
# Out:
# [I 2024-12-02 00:54:58,631] A new study created in memory with name: no-name-8fff5498-fe66-47d5-92e8-c60e0c4c2f61
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:55:08,605] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 83, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 20, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.0.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:55:09,827] Trial 1 finished with value: 0.1686746987951807 and parameters: {'n_estimators': 75, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 1 with value: 0.1686746987951807.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:55:12,369] Trial 2 finished with value: 0.30508474576271183 and parameters: {'n_estimators': 62, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:58:43,179] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 79, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:58:45,514] Trial 4 finished with value: 0.24806201550387594 and parameters: {'n_estimators': 55, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:58:48,665] Trial 5 finished with value: 0.0 and parameters: {'n_estimators': 87, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 00:58:56,057] Trial 6 finished with value: 0.0 and parameters: {'n_estimators': 59, 'max_depth': 25, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:04:45,885] Trial 7 finished with value: 0.0 and parameters: {'n_estimators': 91, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:04:46,811] Trial 8 finished with value: 0.2146341463414634 and parameters: {'n_estimators': 63, 'max_depth': 2, 'min_samples_split': 17, 'min_samples_leaf': 16, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:04:48,131] Trial 9 finished with value: 0.21052631578947367 and parameters: {'n_estimators': 59, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:05:00,644] Trial 10 finished with value: 0.0 and parameters: {'n_estimators': 99, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:05:02,056] Trial 11 finished with value: 0.18652849740932642 and parameters: {'n_estimators': 50, 'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:05:05,819] Trial 12 finished with value: 0.07142857142857144 and parameters: {'n_estimators': 68, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:05:08,238] Trial 13 finished with value: 0.26229508196721313 and parameters: {'n_estimators': 51, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:05:10,942] Trial 14 finished with value: 0.25806451612903225 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:05:14,234] Trial 15 finished with value: 0.2021276595744681 and parameters: {'n_estimators': 69, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:07:37,884] Trial 16 finished with value: 0.045454545454545456 and parameters: {'n_estimators': 65, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:07:45,982] Trial 17 finished with value: 0.0 and parameters: {'n_estimators': 73, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:07:48,277] Trial 18 finished with value: 0.2807017543859649 and parameters: {'n_estimators': 56, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:09:59,430] Trial 19 finished with value: 0.044444444444444446 and parameters: {'n_estimators': 59, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 18, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:07,536] Trial 20 finished with value: 0.0 and parameters: {'n_estimators': 56, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 15, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:10,465] Trial 21 finished with value: 0.24193548387096778 and parameters: {'n_estimators': 53, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:13,122] Trial 22 finished with value: 0.30088495575221236 and parameters: {'n_estimators': 62, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:17,714] Trial 23 finished with value: 0.18461538461538463 and parameters: {'n_estimators': 62, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 19, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:19,891] Trial 24 finished with value: 0.20320855614973263 and parameters: {'n_estimators': 69, 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:26,145] Trial 25 finished with value: 0.0425531914893617 and parameters: {'n_estimators': 65, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 11, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:30,796] Trial 26 finished with value: 0.2542372881355932 and parameters: {'n_estimators': 75, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:34,536] Trial 27 finished with value: 0.11494252873563218 and parameters: {'n_estimators': 56, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:10:36,075] Trial 28 finished with value: 0.0 and parameters: {'n_estimators': 61, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 15, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:04,181] Trial 29 finished with value: 0.0 and parameters: {'n_estimators': 81, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:06,350] Trial 30 finished with value: 0.20408163265306123 and parameters: {'n_estimators': 67, 'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:09,225] Trial 31 finished with value: 0.2439024390243902 and parameters: {'n_estimators': 53, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 11, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:12,792] Trial 32 finished with value: 0.2542372881355932 and parameters: {'n_estimators': 53, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:16,428] Trial 33 finished with value: 0.11494252873563218 and parameters: {'n_estimators': 57, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:21,321] Trial 34 finished with value: 0.10526315789473684 and parameters: {'n_estimators': 73, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:23,699] Trial 35 finished with value: 0.256 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:25,202] Trial 36 finished with value: 0.04081632653061224 and parameters: {'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:16:28,874] Trial 37 finished with value: 0.14084507042253522 and parameters: {'n_estimators': 53, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 18, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:19:53,950] Trial 38 finished with value: 0.0 and parameters: {'n_estimators': 64, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 14, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:19:56,357] Trial 39 finished with value: 0.0 and parameters: {'n_estimators': 57, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:03,905] Trial 40 finished with value: 0.0 and parameters: {'n_estimators': 71, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:06,962] Trial 41 finished with value: 0.25196850393700787 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:10,312] Trial 42 finished with value: 0.16494845360824742 and parameters: {'n_estimators': 54, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:12,409] Trial 43 finished with value: 0.19900497512437812 and parameters: {'n_estimators': 51, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:15,836] Trial 44 finished with value: 0.2735042735042735 and parameters: {'n_estimators': 58, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:19,942] Trial 45 finished with value: 0.24999999999999994 and parameters: {'n_estimators': 78, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:26,471] Trial 46 finished with value: 0.10666666666666667 and parameters: {'n_estimators': 89, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 19, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:20:28,252] Trial 47 finished with value: 0.0 and parameters: {'n_estimators': 59, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 19, 'max_features': 'log2'}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:23:43,076] Trial 48 finished with value: 0.044444444444444446 and parameters: {'n_estimators': 94, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 2 with value: 0.30508474576271183.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-12-02 01:23:44,818] Trial 49 finished with value: 0.20725388601036268 and parameters: {'n_estimators': 63, 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 18, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.30508474576271183.
# Best hyperparameters: {'n_estimators': 62, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 'sqrt'}
# Best precision: 0.30508474576271183

# %% [markdown]
# Best hyperparameters: {'n_estimators': 62, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 'sqrt'}
# Best f1-score: 0.30508474576271183

# %%
param = {'n_estimators': 62, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 'sqrt'}
model = RandomForestClassifier(
    **param,
    random_state=42
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
precision = precision_score(y_test, y_pred)
# Out:
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def classification_metrics(y_test, y_pred):
    print("="*50)
    print("The accuracy score", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 score:", f1_score(y_test, y_pred))
    print("="*50)
    print(classification_report(y_test, y_pred))
    print("="*50)
    print("confusion Matrix")
    print(confusion_matrix(y_test, y_pred))
    print("="*50)

classification_metrics(y_test, y_pred)
# Out:
# ==================================================
# The accuracy score 0.8986666666666666
# Precision: 0.0
# Recall: 0.0
# F1 score: 0.0
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       337
#            1       0.00      0.00      0.00        38
#
#     accuracy                           0.90       375
#    macro avg       0.45      0.50      0.47       375
# weighted avg       0.81      0.90      0.85       375
#
# ==================================================
# confusion Matrix
# [[337   0]
#  [ 38   0]]
# ==================================================
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
