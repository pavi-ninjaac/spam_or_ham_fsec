# %%
import pandas as pd
import optuna


from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, accuracy_score, confusion_matrix

# %%
X_train = pd.read_csv("data/x_train.csv", header=None)
X_test = pd.read_csv("data/x_text.csv", header=None)
y_train = pd.read_csv("data/y_train.csv", header=None)
y_test = pd.read_csv("data/y_test.csv", header=None)



print("X train ",X_train.shape)
print("X test",X_test.shape)
print("Y_Train", y_train.shape)
print("Y_test", y_test.shape)
# Out:
# X train  (3417, 1000)
# X test (375, 1000)
# Y_Train (3417, 1)
# Y_test (375, 1)

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 100)
    max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    precision = precision_score(y_test, y_pred)

    return precision

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

print(f"Best hyperparameters: {study.best_params}")
print(f"Best precision: {study.best_value}")
# Out:
# [I 2024-11-30 22:38:31,376] A new study created in memory with name: no-name-504d2e40-7954-47e1-a5fb-b21ed85d7cbf
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:38:43,238] Trial 0 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 73, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 15, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:38:46,711] Trial 1 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 80, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 14, 'max_features': 'log2'}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:43:46,928] Trial 2 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 55, 'max_depth': 27, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:43:52,828] Trial 3 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 50, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:43:56,763] Trial 4 finished with value: 0.8978494623655914 and parameters: {'n_estimators': 55, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 18, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:06,386] Trial 5 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 89, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:07,017] Trial 6 finished with value: 0.8948948948948949 and parameters: {'n_estimators': 61, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:10,914] Trial 7 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 84, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_features': 'log2'}. Best is trial 0 with value: 0.8986666666666666.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:14,753] Trial 8 finished with value: 0.9027777777777778 and parameters: {'n_estimators': 72, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:15,723] Trial 9 finished with value: 0.8938053097345132 and parameters: {'n_estimators': 69, 'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_features': 'log2'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:21,723] Trial 10 finished with value: 0.8983957219251337 and parameters: {'n_estimators': 96, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:31,603] Trial 11 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 69, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:36,639] Trial 12 finished with value: 0.900804289544236 and parameters: {'n_estimators': 73, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:40,644] Trial 13 finished with value: 0.900804289544236 and parameters: {'n_estimators': 66, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:44,125] Trial 14 finished with value: 0.9002770083102493 and parameters: {'n_estimators': 77, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:48:47,736] Trial 15 finished with value: 0.8997289972899729 and parameters: {'n_estimators': 88, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:51:28,319] Trial 16 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 64, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 8 with value: 0.9027777777777778.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:51:32,228] Trial 17 finished with value: 0.9038461538461539 and parameters: {'n_estimators': 75, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:51:35,050] Trial 18 finished with value: 0.8994565217391305 and parameters: {'n_estimators': 99, 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:18,320] Trial 19 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 83, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:34,036] Trial 20 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 78, 'max_depth': 19, 'min_samples_split': 18, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:43,838] Trial 21 finished with value: 0.8978494623655914 and parameters: {'n_estimators': 73, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 17, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:47,750] Trial 22 finished with value: 0.8983516483516484 and parameters: {'n_estimators': 70, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:52,462] Trial 23 finished with value: 0.8978494623655914 and parameters: {'n_estimators': 75, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:55,205] Trial 24 finished with value: 0.8974358974358975 and parameters: {'n_estimators': 62, 'max_depth': 2, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:54:59,784] Trial 25 finished with value: 0.8983516483516484 and parameters: {'n_estimators': 81, 'max_depth': 3, 'min_samples_split': 14, 'min_samples_leaf': 12, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:55:11,389] Trial 26 finished with value: 0.8983957219251337 and parameters: {'n_estimators': 87, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 16, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:55:41,824] Trial 27 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 73, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:55:53,464] Trial 28 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 92, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:59:15,191] Trial 29 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 67, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:59:27,080] Trial 30 finished with value: 0.9005376344086021 and parameters: {'n_estimators': 76, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:59:34,513] Trial 31 finished with value: 0.9002695417789758 and parameters: {'n_estimators': 66, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 11, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:59:44,069] Trial 32 finished with value: 0.8983957219251337 and parameters: {'n_estimators': 59, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 22:59:54,463] Trial 33 finished with value: 0.900804289544236 and parameters: {'n_estimators': 72, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:00:02,108] Trial 34 finished with value: 0.8977900552486188 and parameters: {'n_estimators': 65, 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:00:15,874] Trial 35 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 79, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 14, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:00:22,518] Trial 36 finished with value: 0.9010695187165776 and parameters: {'n_estimators': 56, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:03:51,574] Trial 37 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 54, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:03:53,291] Trial 38 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 54, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:03:59,511] Trial 39 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 51, 'max_depth': 22, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:01,651] Trial 40 finished with value: 0.8983957219251337 and parameters: {'n_estimators': 60, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': 'log2'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:07,555] Trial 41 finished with value: 0.8983957219251337 and parameters: {'n_estimators': 57, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:13,550] Trial 42 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 71, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 11, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:17,298] Trial 43 finished with value: 0.900804289544236 and parameters: {'n_estimators': 68, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:25,549] Trial 44 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 75, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:30,799] Trial 45 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 63, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:04:33,728] Trial 46 finished with value: 0.8986301369863013 and parameters: {'n_estimators': 81, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 13, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:06:12,207] Trial 47 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 50, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 20, 'max_features': None}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:06:19,211] Trial 48 finished with value: 0.8986666666666666 and parameters: {'n_estimators': 58, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 17 with value: 0.9038461538461539.
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [I 2024-11-30 23:06:20,067] Trial 49 finished with value: 0.8964497041420119 and parameters: {'n_estimators': 85, 'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 11, 'max_features': 'log2'}. Best is trial 17 with value: 0.9038461538461539.
# Best hyperparameters: {'n_estimators': 75, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt'}
# Best precision: 0.9038461538461539

# %% [markdown]
# Best hyperparameters: {'n_estimators': 75, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt'}
# Best precision: 0.9038461538461539

# %%
param = {'n_estimators': 75, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt'}
model = RandomForestClassifier(
    **param,
    random_state=42
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
precision = precision_score(y_test, y_pred)
# Out:
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
def classification_metrics(y_test, y_pred):
    print("="*50)
    print("The accuracy score", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 score:", f1_score(y_test, y_pred))
    print("="*50)
    print(classification_report(y_test, y_pred))
    print("="*50)
    print("confusion Matrix")
    print(confusion_matrix(y_test, y_pred))
    print("="*50)

classification_metrics(y_test, y_pred)
# Out:
# ==================================================
# The accuracy score 0.8853333333333333
# Precision: 0.9038461538461539
# Recall: 0.9762611275964391
# F1 score: 0.9386590584878743
# ==================================================
#               precision    recall  f1-score   support
#
#           -1       0.27      0.08      0.12        38
#            1       0.90      0.98      0.94       337
#
#     accuracy                           0.89       375
#    macro avg       0.59      0.53      0.53       375
# weighted avg       0.84      0.89      0.86       375
#
# ==================================================
# confusion Matrix
# [[  3  35]
#  [  8 329]]
# ==================================================
