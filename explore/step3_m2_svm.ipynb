# %%
import pandas as pd
import optuna


from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, accuracy_score, confusion_matrix

# %%
X_train = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/X_train.csv", header=None)
X_test = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/X_test.csv", header=None)
y_train = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/y_train.csv", header=None)
y_test = pd.read_csv("/home/pavithra/projects/spam_or_ham_fsec/data/target/y_test.csv", header=None)



print("X train ",X_train.shape)
print("X test",X_test.shape)
print("Y_Train", y_train.shape)
print("Y_test", y_test.shape)
# Out:
# X train  (3417, 1000)
# X test (375, 1000)
# Y_Train (3417, 1)
# Y_test (375, 1)

# %%
def objective(trial):
    C = trial.suggest_loguniform('C', 1e-5, 1e5)
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly', 'sigmoid'])
    gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
    degree = trial.suggest_int('degree', 2, 5)

    model = SVC(C=C, kernel=kernel, gamma=gamma, degree=degree, random_state=42)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    precision = precision_score(y_test, y_pred)

    return precision

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)

# Print the best hyperparameters found
print(f"Best hyperparameters: {study.best_params}")
print(f"Best precision: {study.best_value}")


# Ran for 9m 14.4m
# Out:
# [I 2024-11-30 22:31:41,989] A new study created in memory with name: no-name-92840e3e-5b5f-453c-a466-ef717c31cd05
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:31:53,910] Trial 0 finished with value: 0.8986666666666666 and parameters: {'C': 7481.184526410551, 'kernel': 'rbf', 'gamma': 0.05896166958023833, 'degree': 3}. Best is trial 0 with value: 0.8986666666666666.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:31:56,762] Trial 1 finished with value: 0.900804289544236 and parameters: {'C': 0.0009390702552866773, 'kernel': 'linear', 'gamma': 0.005399865112369445, 'degree': 5}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:31:59,696] Trial 2 finished with value: 0.900804289544236 and parameters: {'C': 367.90554067242806, 'kernel': 'linear', 'gamma': 0.00019625984365610315, 'degree': 2}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:02,348] Trial 3 finished with value: 0.900804289544236 and parameters: {'C': 1570.8600821392276, 'kernel': 'linear', 'gamma': 0.03693174697391203, 'degree': 2}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:04,895] Trial 4 finished with value: 0.900804289544236 and parameters: {'C': 1.112113161578957, 'kernel': 'linear', 'gamma': 0.00012136074865602062, 'degree': 4}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:14,079] Trial 5 finished with value: 0.8986666666666666 and parameters: {'C': 0.018095827881057194, 'kernel': 'poly', 'gamma': 0.08717845887045801, 'degree': 3}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:25,382] Trial 6 finished with value: 0.8986666666666666 and parameters: {'C': 0.012827586402213577, 'kernel': 'rbf', 'gamma': 0.0005346494915292948, 'degree': 2}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:35,613] Trial 7 finished with value: 0.8986666666666666 and parameters: {'C': 0.00024200225171662555, 'kernel': 'poly', 'gamma': 7.73578902377373, 'degree': 2}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:49,062] Trial 8 finished with value: 0.8986666666666666 and parameters: {'C': 0.2186027184580826, 'kernel': 'sigmoid', 'gamma': 1.3705476119780542e-05, 'degree': 4}. Best is trial 1 with value: 0.900804289544236.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:32:59,105] Trial 9 finished with value: 0.9393939393939394 and parameters: {'C': 6.616208356432873, 'kernel': 'sigmoid', 'gamma': 0.5499904996919381, 'degree': 5}. Best is trial 9 with value: 0.9393939393939394.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:33:10,974] Trial 10 finished with value: 0.9349112426035503 and parameters: {'C': 10.19595909032691, 'kernel': 'sigmoid', 'gamma': 2.938631642739344, 'degree': 5}. Best is trial 9 with value: 0.9393939393939394.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:33:18,811] Trial 11 finished with value: 0.9352941176470588 and parameters: {'C': 22.35461066227448, 'kernel': 'sigmoid', 'gamma': 4.8157924216413255, 'degree': 5}. Best is trial 9 with value: 0.9393939393939394.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:33
. Best is trial 21 with value: 0.9464285714285714.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:17,720] Trial 30 finished with value: 0.937888198757764 and parameters: {'C': 1059.3588214146575, 'kernel': 'sigmoid', 'gamma': 9.220556362266226, 'degree': 5}. Best is trial 21 with value: 0.9464285714285714.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:26,349] Trial 31 finished with value: 0.9349112426035503 and parameters: {'C': 81.43273509608032, 'kernel': 'sigmoid', 'gamma': 1.7744402477042802, 'degree': 5}. Best is trial 21 with value: 0.9464285714285714.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:35,764] Trial 32 finished with value: 0.937888198757764 and parameters: {'C': 4.187461912823905, 'kernel': 'sigmoid', 'gamma': 0.34360507063825424, 'degree': 5}. Best is trial 21 with value: 0.9464285714285714.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:43,471] Trial 33 finished with value: 0.9467455621301775 and parameters: {'C': 9603.249903565273, 'kernel': 'sigmoid', 'gamma': 1.0159095440362829, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:46,050] Trial 34 finished with value: 0.900804289544236 and parameters: {'C': 7649.32001729512, 'kernel': 'linear', 'gamma': 0.09007174605188094, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:49,035] Trial 35 finished with value: 0.900804289544236 and parameters: {'C': 70331.5151113434, 'kernel': 'linear', 'gamma': 1.0426675149198412, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:36:55,142] Trial 36 finished with value: 0.9216867469879518 and parameters: {'C': 786.679985891423, 'kernel': 'sigmoid', 'gamma': 0.003151299196589755, 'degree': 4}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:37:02,657] Trial 37 finished with value: 0.9310344827586207 and parameters: {'C': 133.19095814725773, 'kernel': 'sigmoid', 'gamma': 3.700013337188334, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:37:05,832] Trial 38 finished with value: 0.900804289544236 and parameters: {'C': 8610.221424794117, 'kernel': 'linear', 'gamma': 0.016180659376655995, 'degree': 4}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:37:15,223] Trial 39 finished with value: 0.8986666666666666 and parameters: {'C': 0.0044503633605302295, 'kernel': 'poly', 'gamma': 0.10897337782322569, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:37:25,828] Trial 40 finished with value: 0.9415204678362573 and parameters: {'C': 2376.3559287749745, 'kernel': 'sigmoid', 'gamma': 0.07354881185992301, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:37:33,753] Trial 41 finished with value: 0.9415204678362573 and parameters: {'C': 2197.9550828109427, 'kernel': 'sigmoid', 'gamma': 0.05323469500603859, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:37:43,322] Trial 42 finished with value: 0.9386503067484663 and parameters: {'C': 19204.484539718545, 'kernel': 'sigmoid', 'gamma': 0.32611290131846915, 'degree': 5}. Best is trial 33 with value: 0.9467455621301775.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:59:33,614] Trial 185 finished with value: 0.9404761904761905 and parameters: {'C': 1.8189154926455107, 'kernel': 'sigmoid', 'gamma': 0.3104561881070311, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:59:47,722] Trial 186 finished with value: 0.936046511627907 and parameters: {'C': 0.21790825428058422, 'kernel': 'sigmoid', 'gamma': 0.6554987350452729, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 22:59:59,120] Trial 187 finished with value: 0.9386503067484663 and parameters: {'C': 2782.624824606938, 'kernel': 'sigmoid', 'gamma': 0.21916765584888764, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:00:06,450] Trial 188 finished with value: 0.9345238095238095 and parameters: {'C': 0.41572537706219986, 'kernel': 'sigmoid', 'gamma': 0.4082378098349442, 'degree': 2}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:00:14,688] Trial 189 finished with value: 0.9464285714285714 and parameters: {'C': 0.7816393342549315, 'kernel': 'sigmoid', 'gamma': 0.14042726489922996, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:00:26,717] Trial 190 finished with value: 0.9457831325301205 and parameters: {'C': 0.8446511290985367, 'kernel': 'sigmoid', 'gamma': 0.08721362137897835, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:00:42,268] Trial 191 finished with value: 0.9411764705882353 and parameters: {'C': 0.984420484401039, 'kernel': 'sigmoid', 'gamma': 0.05244265943276695, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:00:55,718] Trial 192 finished with value: 0.935672514619883 and parameters: {'C': 0.4530838788361858, 'kernel': 'sigmoid', 'gamma': 0.07072727911774718, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:01:09,699] Trial 193 finished with value: 0.9408284023668639 and parameters: {'C': 1.6479261819256452, 'kernel': 'sigmoid', 'gamma': 0.12354972646589563, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:01:20,570] Trial 194 finished with value: 0.9298245614035088 and parameters: {'C': 0.714163264724518, 'kernel': 'sigmoid', 'gamma': 0.030257155888511498, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:01:29,345] Trial 195 finished with value: 0.9393939393939394 and parameters: {'C': 3.681560932258772, 'kernel': 'sigmoid', 'gamma': 0.09560383080728686, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:01:40,841] Trial 196 finished with value: 0.8986666666666666 and parameters: {'C': 0.2720960814812291, 'kernel': 'poly', 'gamma': 0.15273935385129778, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:01:47,969] Trial 197 finished with value: 0.9401197604790419 and parameters: {'C': 0.7981964787099494, 'kernel': 'sigmoid', 'gamma': 0.09024054697371575, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:01:55,477] Trial 198 finished with value: 0.9393939393939394 and parameters: {'C': 2.246935056925249, 'kernel': 'sigmoid', 'gamma': 0.24881637651057265, 'degree': 2}. Best is trial 122 with value: 0.9473684210526315.
# /tmp/ipykernel_192425/2423031644.py:2: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-5, 1e5)
# /tmp/ipykernel_192425/2423031644.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-5, 1e1)
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-11-30 23:02:03,097] Trial 199 finished with value: 0.9382716049382716 and parameters: {'C': 1.1880514450449573, 'kernel': 'sigmoid', 'gamma': 0.1876549874730973, 'degree': 5}. Best is trial 122 with value: 0.9473684210526315.
# Best hyperparameters: {'C': 0.7536299183832335, 'kernel': 'sigmoid', 'gamma': 0.38769439007402395, 'degree': 5}
# Best accuracy: 0.9473684210526315

# %%
Best hyperparameters: {'C': 0.7536299183832335, 'kernel': 'sigmoid', 'gamma': 0.38769439007402395, 'degree': 5}
Best accuracy: 0.9473684210526315
# Out:
#   Cell In[9], line 1
#     Best hyperparameters: {'C': 0.7536299183832335, 'kernel': 'sigmoid', 'gamma': 0.38769439007402395, 'degree': 5}
#          ^
# SyntaxError: invalid syntax

# %%
param = {'C': 0.7536299183832335, 'kernel': 'sigmoid', 'gamma': 0.38769439007402395, 'degree': 5}
model = SVC(**param)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
# Out:
# /home/pavithra/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
def classification_metrics(y_test, y_pred):
    print("="*50)
    print("The accuracy score", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1 score:", f1_score(y_test, y_pred))
    print("="*50)
    print(classification_report(y_test, y_pred))
    print("="*50)
    print("confusion Matrix")
    print(confusion_matrix(y_test, y_pred))
    print("="*50)

classification_metrics(y_test, y_pred)
# Out:
# ==================================================
# The accuracy score 0.5093333333333333
# Precision: 0.9473684210526315
# Recall: 0.4807121661721068
# F1 score: 0.6377952755905512
# ==================================================
#               precision    recall  f1-score   support
#
#           -1       0.14      0.76      0.24        38
#            1       0.95      0.48      0.64       337
#
#     accuracy                           0.51       375
#    macro avg       0.54      0.62      0.44       375
# weighted avg       0.87      0.51      0.60       375
#
# ==================================================
# confusion Matrix
# [[ 29   9]
#  [175 162]]
# ==================================================
